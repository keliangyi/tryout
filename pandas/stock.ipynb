# %%
import tushare as ts
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pro = ts.pro_api('token')
my_stocks = [ 
    '300677.SZ', '600438.SH', '600519.SH', '600006.SH','000725.SZ', '601222.SH', 
    '000858.SZ', '603338.SH', '002475.SZ','603301.SH','603866.SH' 
]

# df.loc[0,:]['xxx']  df 第一行的xxx
# mongo.db.st_stock_daily.find_one({"$query":{ "ts_code":item['ts_code'], }, "$orderby":{ "trade_date": -1 }})
# db.User.update({},{$unset:{'address':''}},false, true)

# %%
# start_date
df = pro.stock_basic().head()
[{ "name":i  } for i in df['industry'].unique()]
# 五粮液 275
# Out:
# [{'name': '银行'},
#  {'name': '全国地产'},
#  {'name': '互联网'},
#  {'name': '环境保护'},
#  {'name': '区域地产'}]

# %%
start_date = '20190101'
riqi = '20201224'
# riqi = '20201012'
# df_arr = []
# for i in my_stocks:    
#     df_arr.append(ts.pro_bar(ts_code=i,adj='qfq',start_date=riqi,end_date=riqi,adjfactor=True))
# df = pd.concat(df_arr, axis=0, join="outer")
# df.set_index('ts_code',inplace=True, drop=True)
df = ts.pro_bar(ts_code='300677.SZ',adj='qfq',start_date=start_date,end_date=riqi,adjfactor=True)
df.set_index('trade_date',inplace=True, drop=False)
df.head()
# Out:
#               ts_code trade_date   open    high     low   close  pre_close  \
# trade_date
# 20201224    300677.SZ   20201224  163.5  165.84  160.00  163.04     164.66
# 20201223    300677.SZ   20201223  166.7  167.94  159.31  164.66     169.21
# 20201222    300677.SZ   20201222  170.1  171.50  163.50  169.21     166.50
# 20201221    300677.SZ   20201221  157.0  166.50  157.00  166.50     155.89
# 20201218    300677.SZ   20201218  157.9  159.85  152.10  155.89     156.91
#
#             change  pct_chg        vol       amount  adj_factor
# trade_date
# 20201224     -1.62  -0.9838   58589.85   955250.158       3.052
# 20201223     -4.55  -2.6890   87987.58  1440457.168       3.052
# 20201222      2.71   1.6276  101128.53  1704814.028       3.052
# 20201221     10.61   6.8061  103583.78  1694593.491       3.052
# 20201218     -1.02  -0.6501   69164.19  1079572.825       3.052

# %%
d = '20201225'
adj = pro.adj_factor(ts_code='300677.SZ',start_date='20201220',)
adj.set_index('trade_date',inplace=True)
adj
# Out:
#               ts_code  adj_factor
# trade_date
# 20201225    300677.SZ       3.052
# 20201224    300677.SZ       3.052
# 20201223    300677.SZ       3.052
# 20201222    300677.SZ       3.052
# 20201221    300677.SZ       3.052

# %%
df = pro.income(ts_code='300677.SZ')
df
# Out:
#       ts_code  ann_date f_ann_date  end_date report_type comp_type  basic_eps  \
# 0   300677.SZ  20201028   20201028  20200930           1         1    20.8300
# 1   300677.SZ  20200828   20200828  20200630           1         1     9.3000
# 2   300677.SZ  20200427   20200427  20200331           1         1     0.6600
# 3   300677.SZ  20200427   20200427  20200331           1         1     0.6600
# 4   300677.SZ  20200427   20200427  20191231           1         1     0.9100
# 5   300677.SZ  20200427   20200427  20191231           1         1     0.9100
# 6   300677.SZ  20191028   20191028  20190930           1         1     0.6412
# 7   300677.SZ  20191028   20191028  20190930           1         1     0.6412
# 8   300677.SZ  20190830   20190830  20190630           1         1     0.3600
# 9   300677.SZ  20190830   20190830  20190630           1         1     0.3600
# 10  300677.SZ  20190429   20190429  20190331           1         1     0.1700
# ...
